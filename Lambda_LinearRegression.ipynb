# %%
#Task 01
x=110
print("Pass") if x>=50 and x<100 else print("Ungraded") if x<0 or x>100 else print("Fail") 


#Task 02
def add(x,y):
    return x+y
print(add(5,6))

#Task 03
import random
import numpy
import matplotlib.pyplot as plt


#way1
randomList = []
for i in range (0,10):
    x= random.randint(0,9)
    randomList.append(x)
print(randomList)
plt.hist(randomList,10)
plt.show()

#way2
x = numpy.random.uniform(0,9,10)
plt.hist(x,10)
plt.show()

#way3
v = random.randint(0,9)
plt.hist(v,10)
plt.show()


#Task 04
from scipy import stats
x = [5,7,8,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,8]
slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(n):
    return slope * n + intercept

speed = myfunc(5)
print(speed)
speed = myfunc(10)
print(speed)
speed = myfunc(15)
print(speed)
speed = myfunc(20)
print(speed)
     

#Task 05
x = [5,7,8,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,8]
slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(n):
    return slope * n + intercept

mymodel = list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show()
# Out:
# Ungraded
# 11
# [5, 3, 9, 1, 5, 8, 6, 2, 7, 5]
# 79.61980830670926
# 87.20766773162939
# 94.79552715654953
# 102.38338658146965
